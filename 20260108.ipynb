# %% [markdown]
# ### Pandas

# %%
# %pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.read_csv('heroes.csv')
df
# Out:
#       이름  나이     직업     국적    키            재산
# 0   아이언맨  58    CEO     미국  174  1.150000e+10
# 1     토르  45      신  아스가르드  190           NaN
# 2  스파이더맨  18   고등학생     미국  177  6.000000e+02
# 3   원더우먼  27     공주  데미스키라  178           NaN
# 4     헐크  33  핵물리학자     미국  270  1.000000e+09
# 5   캡틴마블  25    파일럿     미국  170  3.400000e+08
# 6  블랙위도우  32    스파이    러시아  170  5.000000e+07

# %%
pd.options.display.float_format = '{:.0f}'.format

# %%
df
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df.head()
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000

# %%
df.tail()
# Out:
#       이름  나이     직업     국적    키         재산
# 2  스파이더맨  18   고등학생     미국  177        600
# 3   원더우먼  27     공주  데미스키라  178        NaN
# 4     헐크  33  핵물리학자     미국  270 1000000000
# 5   캡틴마블  25    파일럿     미국  170  340000000
# 6  블랙위도우  32    스파이    러시아  170   50000000

# %%
df.sample(5)
# Out:
#       이름  나이     직업     국적    키         재산
# 1     토르  45      신  아스가르드  190        NaN
# 6  블랙위도우  32    스파이    러시아  170   50000000
# 4     헐크  33  핵물리학자     미국  270 1000000000
# 2  스파이더맨  18   고등학생     미국  177        600
# 3   원더우먼  27     공주  데미스키라  178        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      7 non-null      object
#  1   나이      7 non-null      int64
#  2   직업      7 non-null      object
#  3   국적      7 non-null      object
#  4   키       7 non-null      int64
#  5   재산      5 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 468.0+ bytes

# %%
df.describe()
# Out:
#        나이   키          재산
# count   7   7           5
# mean   34 190  2578000120
# std    13  36  5003440739
# min    18 170         600
# 25%    26 172    50000000
# 50%    32 177   340000000
# 75%    39 184  1000000000
# max    58 270 11500000000

# %%
df.head()
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000

# %%
df['국적'].unique()
# Out:
# array(['미국', '아스가르드', '데미스키라', '러시아'], dtype=object)

# %%
df['국적'].value_counts()
# Out:
# 국적
# 미국       4
# 아스가르드    1
# 데미스키라    1
# 러시아      1
# Name: count, dtype: int64

# %%
df['나이'].nlargest()
# Out:
# 0    58
# 1    45
# 4    33
# 6    32
# 3    27
# Name: 나이, dtype: int64

# %%
df.nlargest(7, '키')
# Out:
#       이름  나이     직업     국적    키          재산
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 1     토르  45      신  아스가르드  190         NaN
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 0   아이언맨  58    CEO     미국  174 11500000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
# 키가 큰 순서대로 7명을 정렬

# %%
# 데이터 일부분 선택

# %%
df[['이름', '직업']]
# Out:
#       이름     직업
# 0   아이언맨    CEO
# 1     토르      신
# 2  스파이더맨   고등학생
# 3   원더우먼     공주
# 4     헐크  핵물리학자
# 5   캡틴마블    파일럿
# 6  블랙위도우    스파이

# %%
type(df['이름'])
# Out:
# pandas.core.frame.DataFrame

# %%
# 시리즈 데이터에서 일부 데이터 슬라이싱 하기
df['이름'][:5]
# Out:
# 0     아이언맨
# 1       토르
# 2    스파이더맨
# 3     원더우먼
# 4       헐크
# Name: 이름, dtype: object

# %%
df['이름'][4]
# Out:
# '헐크'

# %%
df[4:]
# Out:
#       이름  나이     직업   국적    키         재산
# 4     헐크  33  핵물리학자   미국  270 1000000000
# 5   캡틴마블  25    파일럿   미국  170  340000000
# 6  블랙위도우  32    스파이  러시아  170   50000000

# %%
df[4, '이름']

# %%
df.iloc -> 순서(정수)로 데이터 검색
df.loc -> 이름(label)로 데이터 검색

# %%
df.iloc[행번호, 열번호]

# %%
df.iloc[:4]
# Out:
#       이름  나이    직업     국적    키          재산
# 0   아이언맨  58   CEO     미국  174 11500000000
# 1     토르  45     신  아스가르드  190         NaN
# 2  스파이더맨  18  고등학생     미국  177         600
# 3   원더우먼  27    공주  데미스키라  178         NaN

# %%
df.iloc[4]
# Out:
# 이름           헐크
# 나이           33
# 직업        핵물리학자
# 국적           미국
# 키           270
# 재산   1000000000
# Name: 4, dtype: object

# %%
df
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df.iloc[[1, 3, 6]]
# Out:
#       이름  나이   직업     국적    키       재산
# 1     토르  45    신  아스가르드  190      NaN
# 3   원더우먼  27   공주  데미스키라  178      NaN
# 6  블랙위도우  32  스파이    러시아  170 50000000

# %%
df.iloc[:5,:3]
# Out:
#       이름  나이     직업
# 0   아이언맨  58    CEO
# 1     토르  45      신
# 2  스파이더맨  18   고등학생
# 3   원더우먼  27     공주
# 4     헐크  33  핵물리학자

# %%
df.loc[행이름, 열이름]

# %%
df.loc[2]
# Out:
# 이름    스파이더맨
# 나이       18
# 직업     고등학생
# 국적       미국
# 키       177
# 재산      600
# Name: 2, dtype: object

# %%
df.loc[[0, 4, 6]]
# Out:
#       이름  나이     직업   국적    키          재산
# 0   아이언맨  58    CEO   미국  174 11500000000
# 4     헐크  33  핵물리학자   미국  270  1000000000
# 6  블랙위도우  32    스파이  러시아  170    50000000

# %%
df.iloc[2: 5]
# Out:
#       이름  나이     직업     국적    키         재산
# 2  스파이더맨  18   고등학생     미국  177        600
# 3   원더우먼  27     공주  데미스키라  178        NaN
# 4     헐크  33  핵물리학자     미국  270 1000000000

# %%
df.loc[2: 5]
# Out:
#       이름  나이     직업     국적    키         재산
# 2  스파이더맨  18   고등학생     미국  177        600
# 3   원더우먼  27     공주  데미스키라  178        NaN
# 4     헐크  33  핵물리학자     미국  270 1000000000
# 5   캡틴마블  25    파일럿     미국  170  340000000

# %%
df.loc[3,'이름']
# Out:
# '원더우먼'

# %%
df
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df.loc[0:2,'이름':'직업']
# Out:
#       이름  나이    직업
# 0   아이언맨  58   CEO
# 1     토르  45     신
# 2  스파이더맨  18  고등학생

# %%
df.loc[0:2,['이름','직업']]
# Out:
#       이름    직업
# 0   아이언맨   CEO
# 1     토르     신
# 2  스파이더맨  고등학생

# %%
# 나이 30살 이상인 레코드만 추출

df.loc[df['나이'] >= 30]
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df.loc[df['직업'] == '스파이', ['이름', '국적']]
# Out:
#       이름   국적
# 6  블랙위도우  러시아

# %%
df['나이'] >= 30
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# Name: 나이, dtype: bool

# %%
df
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
# 미션: 나이가 30초과, 50미만인 레코드만 추출
df[(df['나이'] > 30) & (df['나이'] < 50)]
# Out:
#       이름  나이     직업     국적    키         재산
# 1     토르  45      신  아스가르드  190        NaN
# 4     헐크  33  핵물리학자     미국  270 1000000000
# 6  블랙위도우  32    스파이    러시아  170   50000000

# %%
(df['나이'] > 30) & (df['나이'] < 50)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# Name: 나이, dtype: bool

# %%
# 미션: 키가 180이상인 이름과 나이 컬럼만 추출

# %%
df
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df['국적'] = ['미국','아스가르드','미국','데미스키라', '미국', '미국','러시아'  ]
df
# Out:
#       이름  나이     직업     국적    키          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df['전투력'] = [90, 60, 70, 98, 44, 55, 66]
df
# Out:
#       이름  나이     직업     국적    키          재산  전투력
# 0   아이언맨  58    CEO     미국  174 11500000000   90
# 1     토르  45      신  아스가르드  190         NaN   60
# 2  스파이더맨  18   고등학생     미국  177         600   70
# 3   원더우먼  27     공주  데미스키라  178         NaN   98
# 4     헐크  33  핵물리학자     미국  270  1000000000   44
# 5   캡틴마블  25    파일럿     미국  170   340000000   55
# 6  블랙위도우  32    스파이    러시아  170    50000000   66

# %%
df['전투력'] = df['전투력'] - 5
df
# Out:
#       이름  나이     직업     국적    키          재산  전투력
# 0   아이언맨  58    CEO     미국  174 11500000000   85
# 1     토르  45      신  아스가르드  190         NaN   55
# 2  스파이더맨  18   고등학생     미국  177         600   65
# 3   원더우먼  27     공주  데미스키라  178         NaN   93
# 4     헐크  33  핵물리학자     미국  270  1000000000   39
# 5   캡틴마블  25    파일럿     미국  170   340000000   50
# 6  블랙위도우  32    스파이    러시아  170    50000000   61

# %%
df.columns = ['이름', '연령', '직업', '국적', '신장', '재산', '파워']
df
# Out:
#       이름  연령     직업     국적   신장          재산  파워
# 0   아이언맨  58    CEO     미국  174 11500000000  85
# 1     토르  45      신  아스가르드  190         NaN  55
# 2  스파이더맨  18   고등학생     미국  177         600  65
# 3   원더우먼  27     공주  데미스키라  178         NaN  93
# 4     헐크  33  핵물리학자     미국  270  1000000000  39
# 5   캡틴마블  25    파일럿     미국  170   340000000  50
# 6  블랙위도우  32    스파이    러시아  170    50000000  61

# %%
df.rename(columns = {'이름':'성명','연령': '나이'}, inplace=True)

# %%
df = df.rename(columns = {'이름':'성명','연령': '나이'})

# %%
df.drop(columns=['파워'], inplace=True)

# %%
df
# Out:
#       이름  연령     직업     국적   신장          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      7 non-null      object
#  1   연령      7 non-null      int64
#  2   직업      7 non-null      object
#  3   국적      7 non-null      object
#  4   신장      7 non-null      int64
#  5   재산      5 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 468.0+ bytes

# %%
# 결측치 처리

df[df['재산'].isnull()]
# Out:
#      이름  연령  직업     국적   신장  재산
# 1    토르  45   신  아스가르드  190 NaN
# 3  원더우먼  27  공주  데미스키라  178 NaN

# %%
df.dropna()
# Out:
#       이름  연령     직업   국적   신장          재산
# 0   아이언맨  58    CEO   미국  174 11500000000
# 2  스파이더맨  18   고등학생   미국  177         600
# 4     헐크  33  핵물리학자   미국  270  1000000000
# 5   캡틴마블  25    파일럿   미국  170   340000000
# 6  블랙위도우  32    스파이  러시아  170    50000000

# %%
df
# Out:
#       이름  연령     직업     국적   신장          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190         NaN
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178         NaN
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df['재산'] = df['재산'].fillna(df['재산'].mean())

# %%
df.fillna(method='ffill')
df.ffill()

# %%
df['재산'].mean()
# Out:
# np.float64(2578000120.0)

# %%
df
# Out:
#       이름  연령     직업     국적   신장          재산
# 0   아이언맨  58    CEO     미국  174 11500000000
# 1     토르  45      신  아스가르드  190  2578000120
# 2  스파이더맨  18   고등학생     미국  177         600
# 3   원더우먼  27     공주  데미스키라  178  2578000120
# 4     헐크  33  핵물리학자     미국  270  1000000000
# 5   캡틴마블  25    파일럿     미국  170   340000000
# 6  블랙위도우  32    스파이    러시아  170    50000000

# %%
df.groupby('국적')['연령'].mean()
# Out:
# 국적
# 데미스키라   27
# 러시아     32
# 미국      34
# 아스가르드   45
# Name: 연령, dtype: float64

# %%
df.isnull().sum()
# Out:
# 이름    0
# 연령    0
# 직업    0
# 국적    0
# 신장    0
# 재산    2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      7 non-null      object
#  1   연령      7 non-null      int64
#  2   직업      7 non-null      object
#  3   국적      7 non-null      object
#  4   신장      7 non-null      int64
#  5   재산      7 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 468.0+ bytes

# %%
def add_cm(height):
    return str(height) + 'cm'

df['신장'].apply(add_cm)
# Out:
# 0    174cm
# 1    190cm
# 2    177cm
# 3    178cm
# 4    270cm
# 5    170cm
# 6    170cm
# Name: 신장, dtype: object

# %%
# 미션
df = pd.read_csv('sales_data.csv')
user_df = pd.read_csv('user_data.csv')

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df
# Out:
#   customer_id  order_date product_category   amount channel  discount_rate
# 0        C001  2025-09-01               가전  1200000     온라인           0.10
# 1        C002  2025-09-01             주방용품    45000    오프라인           0.05
# 2        C003  2025-09-02              식료품    12000     온라인            NaN
# 3        C001  2025-09-02               의류    89000     온라인           0.15
# 4        C004  2025-09-03             주방용품    21000     온라인           0.00
# 5        C002  2025-09-03               가전  2500000    오프라인           0.05
# 6        C005  2025-09-04               도서     9900     온라인           0.00
# 7        C003  2025-09-04             주방용품    62000    오프라인            NaN
# 8        C001  2025-09-05              식료품     8500     온라인           0.00
# 9        C004  2025-09-05               의류   150000     온라인           0.20

# %%
# 컬럼명을 한글로 변경
# '고객ID', '구매일자', '제품분류', '구매금액', '구매채널', '할인율'
# '고객ID', '고객명', '가입지역'
df.columns = ['고객ID', '구매일자', '제품분류', '구매금액', '구매채널', '할인율']

# %%
user_df.columns = ['고객ID', '고객명', '가입지역']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고객ID    10 non-null     object
#  1   구매일자    10 non-null     object
#  2   제품분류    10 non-null     object
#  3   구매금액    10 non-null     int64
#  4   구매채널    10 non-null     object
#  5   할인율     8 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 612.0+ bytes

# %%
df.describe()
# Out:
#             구매금액  할인율
# count      10.00 8.00
# mean   409740.00 0.07
# std    819768.03 0.08
# min      8500.00 0.00
# 25%     14250.00 0.00
# 50%     53500.00 0.05
# 75%    134750.00 0.11
# max   2500000.00 0.20

# %%
# 구매금액이 10000원 이상인 데이터만 필터링
df[df['구매금액'] >= 10000]
# Out:
#    고객ID        구매일자  제품분류     구매금액  구매채널  할인율
# 0  C001  2025-09-01    가전  1200000   온라인 0.10
# 1  C002  2025-09-01  주방용품    45000  오프라인 0.05
# 2  C003  2025-09-02   식료품    12000   온라인  NaN
# 3  C001  2025-09-02    의류    89000   온라인 0.15
# 4  C004  2025-09-03  주방용품    21000   온라인 0.00
# 5  C002  2025-09-03    가전  2500000  오프라인 0.05
# 7  C003  2025-09-04  주방용품    62000  오프라인  NaN
# 9  C004  2025-09-05    의류   150000   온라인 0.20

# %%
# '온라인' 채널에서 발생한 구매 중 5000원 이상인 것만 필터링
df[(df['구매채널'] == '온라인') & (df['구매금액'] >= 5000)]
# Out:
#    고객ID        구매일자  제품분류     구매금액 구매채널  할인율
# 0  C001  2025-09-01    가전  1200000  온라인 0.10
# 2  C003  2025-09-02   식료품    12000  온라인  NaN
# 3  C001  2025-09-02    의류    89000  온라인 0.15
# 4  C004  2025-09-03  주방용품    21000  온라인 0.00
# 6  C005  2025-09-04    도서     9900  온라인 0.00
# 8  C001  2025-09-05   식료품     8500  온라인 0.00
# 9  C004  2025-09-05    의류   150000  온라인 0.20

# %%
# '가전', '주방용품' 에 속하는 데이터만 필터링
# df[(df['제품분류'] == '가전') | (df['제품분류'] == '주방용품')]
df[df['제품분류'].isin(['가전', '주방용품'])]
# Out:
#    고객ID        구매일자  제품분류     구매금액  구매채널  할인율
# 0  C001  2025-09-01    가전  1200000   온라인 0.10
# 1  C002  2025-09-01  주방용품    45000  오프라인 0.05
# 4  C004  2025-09-03  주방용품    21000   온라인 0.00
# 5  C002  2025-09-03    가전  2500000  오프라인 0.05
# 7  C003  2025-09-04  주방용품    62000  오프라인  NaN

# %%
# 각 열별 결측치 개수 확인
df.isnull().sum()
# Out:
# 고객ID    0
# 구매일자    0
# 제품분류    0
# 구매금액    0
# 구매채널    0
# 할인율     2
# dtype: int64

# %%
# 결측치가 있는 행 전체 삭제 - 덮어쓰지 마시고 확인만(출력창에 출력만)
df.dropna()
# Out:
#    고객ID        구매일자  제품분류     구매금액  구매채널  할인율
# 0  C001  2025-09-01    가전  1200000   온라인 0.10
# 1  C002  2025-09-01  주방용품    45000  오프라인 0.05
# 3  C001  2025-09-02    의류    89000   온라인 0.15
# 4  C004  2025-09-03  주방용품    21000   온라인 0.00
# 5  C002  2025-09-03    가전  2500000  오프라인 0.05
# 6  C005  2025-09-04    도서     9900   온라인 0.00
# 8  C001  2025-09-05   식료품     8500   온라인 0.00
# 9  C004  2025-09-05    의류   150000   온라인 0.20

# %%
# 특정 값으로 결측치 채우기(덮어쓰기)
df['할인율'].fillna(0, inplace=True)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_6432\1389984181.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['할인율'].fillna(0, inplace=True)

# %%
df
# Out:
#    고객ID        구매일자  제품분류     구매금액  구매채널  할인율      실구매금액 고객등급
# 0  C001  2025-09-01    가전  1200000   온라인 0.10 1080000.00  VIP
# 1  C002  2025-09-01  주방용품    45000  오프라인 0.05   42750.00  VIP
# 2  C003  2025-09-02   식료품    12000   온라인 0.00   12000.00  VIP
# 3  C001  2025-09-02    의류    89000   온라인 0.15   75650.00  VIP
# 4  C004  2025-09-03  주방용품    21000   온라인 0.00   21000.00  VIP
# 5  C002  2025-09-03    가전  2500000  오프라인 0.05 2375000.00  VIP
# 6  C005  2025-09-04    도서     9900   온라인 0.00    9900.00   일반
# 7  C003  2025-09-04  주방용품    62000  오프라인 0.00   62000.00  VIP
# 8  C001  2025-09-05   식료품     8500   온라인 0.00    8500.00   일반
# 9  C004  2025-09-05    의류   150000   온라인 0.20  120000.00  VIP

# %%
# 기존 열을 이용해 새로운 열 생성 
# 할인률이 적용된 df['실구매금액'] 새롭게 생성
df['실구매금액'] = df['구매금액'] * (1-df['할인율'] )

# %%
# 고객 등급을 'VIP'와 '일반'으로 나누기(구매금액이 10000 이상이면 VIP)
df['고객등급'] = df['구매금액'].apply(lambda x: 'VIP' if x >= 10000 else '일반')

# %%
# 제품분류별 구매금액의 평균 구하기
df.groupby('제품분류')['구매금액'].mean()
# Out:
# 제품분류
# 가전     1850000.00
# 도서        9900.00
# 식료품      10250.00
# 의류      119500.00
# 주방용품     42666.67
# Name: 구매금액, dtype: float64

# %%
# 구매채널별로 그룹화하여, 구매금액의 총합과 평균 동시 구하기
df.groupby('구매채널')['구매금액'].agg(['mean', 'sum'])
# Out:
#           mean      sum
# 구매채널
# 오프라인 869000.00  2607000
# 온라인  212914.29  1490400

# %%
merged_df = pd.merge(df, user_df, on='고객ID')

# %%
merged_df

# %%
# csv 파일로 저장
merged_df.to_csv('sales_report.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### matplotlib

# %%
# %pip install matplotlib

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
plt.figure(figsize=(6, 3))
plt.plot([1, 2, 3], [10, 20, 15])
plt.title('간단한 플롯')
plt.show()

# %% [markdown]
# #### 선그래프

# %%
# 선 그래프
plt.plot(x_data, y_data)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# --- 데이터 생성---
data = {
    '월': pd.to_datetime(['2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01', '2025-05-01', '2025-06-01']),
    '방문자수': [1500, 1800, 1700, 2100, 2500, 2300]
}
df_line = pd.DataFrame(data)

plt.figure(figsize=(8, 4)) # figsize 설정

# 1. 플롯 그리기
plt.plot(
    df_line['월'], 
    df_line['방문자수'] #, 
    # marker='o', 
    # linestyle='-', 
    # color='dodgerblue'
)

# 2. 그래프 꾸미기 (ax.set_ 대신 plt. 사용)
plt.title('2025년 상반기 월별 웹사이트 방문자 수', fontsize=16)
plt.xlabel('월', fontsize=12)
plt.ylabel('방문자 수 (명)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# #### 바 차트

# %%
plt.bar()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    '부서': ['영업1팀', '영업2팀', '마케팅팀', '기술지원팀'],
    '실적(억원)': [12, 15, 8, 5]
}
df_bar = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
bars = plt.bar(
    df_bar['부서'], 
    df_bar['실적(억원)'], 
    color=['#FF5733', '#33FF57', '#3357FF', '#FF33A1']
)
plt.title('2023년 3분기 부서별 판매 실적', fontsize=16)
plt.xlabel('부서', fontsize=12)
plt.ylabel('실적 (억원)', fontsize=12)

# 각 바 위에 실제 값 표시 (plt.text 사용)
for bar in bars:
    yval = bar.get_height()
    # plt.text(x좌표, y좌표, 내용, 정렬방식)
    plt.text(
        bar.get_x() + bar.get_width()/2.0, 
        yval, 
        f'{yval}억', 
        va='bottom', 
        ha='center'
    )

plt.show()

# %% [markdown]
# #### 산점도 scatter plot

# %%
# 산점도 scatter plot

# %%
plt.scatter()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)
advertising_cost = np.random.randint(10, 100, 50)
sales = advertising_cost * 1.5 + np.random.normal(0, 10, 50)

plt.figure(figsize=(10, 6))
plt.scatter(
    advertising_cost, 
    sales, 
    alpha=0.7, 
    edgecolors='w', 
    s=80
)

plt.title('광고비와 매출의 관계', fontsize=16)
plt.xlabel('광고비 (만원)', fontsize=12)
plt.ylabel('매출 (만원)', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()

# %%
plt.scatter(
    advertising_cost, 
    sales, 
    c=sales,          # 매출 값에 따라 색상 부여
    cmap='viridis',   # 색상 지도 설정
    alpha=0.8, 
    edgecolors='w', 
    s=sales * 2       # 매출이 클수록 점도 크게
)
plt.colorbar(label='매출 규모') # 색상 막대 추가

# %% [markdown]
# #### 히스토그램

# %%
plt.hist()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)
customer_ages = np.random.normal(loc=35, scale=10, size=200).astype(int)

plt.figure(figsize=(10, 6))
plt.hist(
    customer_ages, 
    bins=15, 
    color='skyblue', 
    edgecolor='black'
)

plt.title('고객 연령 분포', fontsize=16)
plt.xlabel('나이', fontsize=12)
plt.ylabel('고객 수 (빈도)', fontsize=12)

plt.show()

# %% [markdown]
# #### 히트맵

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.rand(8, 10)
rows = [f'Row{i+1}' for i in range(data.shape[0])]
cols = [f'Col{i+1}' for i in range(data.shape[1])]

plt.figure(figsize=(6, 3))
im = plt.imshow(data, cmap='coolwarm')
plt.colorbar(im)
plt.xticks(np.arange(data.shape[1]), labels=cols)
plt.yticks(np.arange(data.shape[0]), labels=rows)
plt.tick_params(top=True, bottom=False, labeltop=True, labelbottom=False)
plt.setp(plt.gca().get_xticklabels(), rotation=-30, ha="right", rotation_mode="anchor")

# 각 셀에 텍스트 추가 (Annotation)
for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        # plt.text(x, y, s) 순서입니다.
        plt.text(j, i, f'{data[i, j]:.2f}',
                 ha="center", va="center", color="w")

plt.title("Heatmap using Matplotlib", pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(data, annot=True, fmt=".2f", cmap='coolwarm', xticklabels=cols, yticklabels=rows)
plt.show()

# %%
merged_df
# Out:
#    고객ID        구매일자  제품분류     구매금액  구매채널  할인율      실구매금액 고객등급  고객명 가입지역
# 0  C001  2025-09-01    가전  1200000   온라인 0.10 1080000.00  VIP  김민준   서울
# 1  C002  2025-09-01  주방용품    45000  오프라인 0.05   42750.00  VIP  이서연   부산
# 2  C003  2025-09-02   식료품    12000   온라인 0.00   12000.00  VIP  박도윤   인천
# 3  C001  2025-09-02    의류    89000   온라인 0.15   75650.00  VIP  김민준   서울
# 4  C004  2025-09-03  주방용품    21000   온라인 0.00   21000.00  VIP  최지우   서울
# 5  C002  2025-09-03    가전  2500000  오프라인 0.05 2375000.00  VIP  이서연   부산
# 6  C005  2025-09-04    도서     9900   온라인 0.00    9900.00   일반  정하은   광주
# 7  C003  2025-09-04  주방용품    62000  오프라인 0.00   62000.00  VIP  박도윤   인천
# 8  C001  2025-09-05   식료품     8500   온라인 0.00    8500.00   일반  김민준   서울
# 9  C004  2025-09-05    의류   150000   온라인 0.20  120000.00  VIP  최지우   서울

# %%
sns.barplot(x=['A', 'B'], y=[10, 20])
plt.title("Seaborn Plot with Matplotlib Title")
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 0         16.99 1.01  Female     No   Sun  Dinner     2
# 1         10.34 1.66    Male     No   Sun  Dinner     3
# 2         21.01 3.50    Male     No   Sun  Dinner     3
# 3         23.68 3.31    Male     No   Sun  Dinner     2
# 4         24.59 3.61  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2
# 242       17.82 1.75    Male     No   Sat  Dinner     2
# 243       18.78 3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", s=100)
plt.title("총 결제금액과 팁의 관계 (흡연 여부별)")
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")
plt.show()

# %%
sns.pairplot(tips, hue="smoker")
plt.show()

# %%
# 시각화 미션

# 제품분류별 매출 비중(Bar Chart) - 어떤 카테고리가 가장 수익이 높은지
# 고객등급별 구매금액 분포 (Box Plot) - VIP와 일반 고객의 구매 단가 차이 확인
# 일자별 매출 추이 (Line Plot) - 시간의 흐름에 따라 매출이 어떻게 변하는지
# 지역별 온라인 주문의 비중

# %%
merged_df = pd.read_csv('sales_report.csv')

# %%
merged_df['총구매금액'] = merged_df.groupby('고객명')['구매금액'].transform('sum')

# 100마넌 이상인 고객이 VIP

# %%
sns.barplot(data = merged_df, x='제품분류', y='구매금액')
plt.title("제품 분류별 매출")
plt.show()

# %%
sns.boxplot(x="고객등급", y="구매금액",
            hue="고객등급", palette=["m", "g"],
            data=merged_df)
plt.title("고객등급별 구매금액 분포")
plt.show()

# %%
daily_sales = merged_df.groupby('구매일자')['구매금액'].sum()
daily_sales
# Out:
# 구매일자
# 2025-09-01    1245000
# 2025-09-02     101000
# 2025-09-03    2521000
# 2025-09-04      71900
# 2025-09-05     158500
# Name: 구매금액, dtype: int64

# %%
plt.plot(
    daily_sales.index, 
    daily_sales
)
plt.title("일자별 매출 추이")
plt.show()
